# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv('placement.csv')
df.head()
# Out:
#    cgpa   ctc
# 0  6.89  3.26
# 1  5.12  1.98
# 2  7.82  3.25
# 3  7.42  3.67
# 4  6.94  3.57

# %%
plt.scatter(df['cgpa'],df['ctc'])
plt.xlabel('CGPA')
plt.ylabel('CTC(in Lacs per annum)')
# Out:
# Text(0, 0.5, 'CTC(in Lacs per annum)')

# %%
X = df.iloc[:,0:1]
y = df.iloc[:,-1]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=2)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
lr.predict(X_test.iloc[0].values.reshape(1,1))
# Out:
# array([3.89111601])

# %%
plt.scatter(df['cgpa'],df['ctc'])
plt.plot(X_train,lr.predict(X_train),color='red')
plt.xlabel('CGPA')
plt.ylabel('CTC')
# Out:
# Text(0, 0.5, 'CTC')

# %%
# m
lr.coef_
# Out:
# array([0.55795197])

# %%
#b
lr.intercept_
# Out:
# -0.8961119222429144
